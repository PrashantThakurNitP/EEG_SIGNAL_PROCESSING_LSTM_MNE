# %%
data_no=input()
# Out:
# 5

# %%
ji=data_no

# %% [markdown]
# ji=data_no

# %%
# !pip install mne
# Out:
# Collecting mne
#   Downloading https://files.pythonhosted.org/packages/92/ab/9b79f927b599da515335afb4b666a7bb336930a6d8345e7b483a9980a9c1/mne-0.20.7-py3-none-any.whl (6.6MB)
#      |████████████████████████████████| 6.6MB 4.3MB/s
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from mne) (1.18.5)
# Requirement already satisfied: scipy>=0.17.1 in /usr/local/lib/python3.6/dist-packages (from mne) (1.4.1)
# Installing collected packages: mne
# Successfully installed mne-0.20.7

# %%
import numpy as np
import mne
import matplotlib.pyplot as plt
import matplotlib

# %%
path='/content/drive/My Drive/EEG SIGNAL PROCESSING NEW/sourcedata (1)/sub-01/eeg/'

# %%
filename="sub-01_ses-"+ji+"_task-BreathCounting_eeg.bdf"

# %%
filename
# Out:
# 'sub-01_ses-5_task-BreathCounting_eeg.bdf'

# %%
rawPath=path+filename

# %%
rawPath
# Out:
# '/content/drive/My Drive/EEG SIGNAL PROCESSING NEW/sourcedata (1)/sub-01/eeg/sub-01_ses-5_task-BreathCounting_eeg.bdf'

# %%
#rawPath='/content/drive/My Drive/Colab Notebooks/sourcedata/sub-01/eeg/sub-01_ses-10_task-BreathCounting_eeg.bdf'
raw=mne.io.read_raw_bdf(rawPath,preload=True)
# Out:
# Extracting EDF parameters from /content/drive/My Drive/EEG SIGNAL PROCESSING NEW/sourcedata (1)/sub-01/eeg/sub-01_ses-5_task-BreathCounting_eeg.bdf...
# BDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 1861631  =      0.000 ...  1817.999 secs...

# %%
print(raw)
print(raw.info)
# Out:
# <RawEDF | sub-01_ses-5_task-BreathCounting_eeg.bdf, 80 x 1861632 (1818.0 s), ~1.11 GB, data loaded>
# <Info | 7 non-empty values
#  bads: []
#  ch_names: Fp1, AF7, AF3, F1, F3, F5, F7, FT7, FC5, FC3, FC1, C1, C3, C5, ...
#  chs: 79 EEG, 1 STIM
#  custom_ref_applied: False
#  highpass: 0.0 Hz
#  lowpass: 208.0 Hz
#  meas_date: 2010-04-21 17:48:20 UTC
#  nchan: 80
#  projs: []
#  sfreq: 1024.0 Hz
# >

# %%
raw.copy().pick_types(stim=True).plot()

# %%
events = mne.find_events(raw,initial_event=True)
print(events)
# Out:
# 1284 events found
# Event IDs: [   10    20    21    30    31    50 65536]
# [[      0       0   65536]
#  [   9918       0      10]
#  [  10961       0      10]
#  ...
#  [1846862       0      31]
#  [1846907       0      20]
#  [1847077       0      50]]

# %%
#interpolate empty data
raw.interpolate_bads(reset_bads=False)
# Out:
# <ipython-input-14-2f5c9d7e3f69>:2: RuntimeWarning: No bad channels to interpolate. Doing nothing...
#   raw.interpolate_bads(reset_bads=False)
# <RawEDF | sub-01_ses-5_task-BreathCounting_eeg.bdf, 80 x 1861632 (1818.0 s), ~1.11 GB, data loaded>

# %%
raw.plot(events=events, start=5, duration=100, color='gray',
         event_color={10: 'r', 20: 'g', 21: 'b', 30: 'm', 31: 'y', 50: 'k'})

# %%
raw.filter(l_freq=0.5,h_freq=50)
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 6759 samples (6.601 sec)
# <RawEDF | sub-01_ses-5_task-BreathCounting_eeg.bdf, 80 x 1861632 (1818.0 s), ~1.11 GB, data loaded>

# %%
raw.resample(sfreq=200)
# Out:
# Trigger channel has a non-zero initial value of 65536 (consider using initial_event=True to detect this event)
# Removing orphaned offset at the beginning of the file.
# 1283 events found
# Event IDs: [10 20 21 30 31 50]
# Trigger channel has a non-zero initial value of 65536 (consider using initial_event=True to detect this event)
# Removing orphaned offset at the beginning of the file.
# 1283 events found
# Event IDs: [10 20 21 30 31 50]
# <RawEDF | sub-01_ses-5_task-BreathCounting_eeg.bdf, 80 x 363600 (1818.0 s), ~222.1 MB, data loaded>

# %%
ica = mne.preprocessing.ICA(n_components=20, random_state=0)

# %%
ica.fit(raw.copy())
# Out:
# Fitting ICA to data using 79 channels (please be patient, this may take a while)
# Inferring max_pca_components from picks
# Selecting by number: 20 components
# Fitting ICA took 20.8s.
# <ICA  |  raw data decomposition, fit (fastica): 363600 samples, 20 components, channels used: "eeg">

# %%
mne.viz.plot_events(events[:500]);

# %%
event_ids = {"qsn start":30,"qsn end":31,"start count":50}

epochs = mne.Epochs(raw, events, event_id=event_ids)
# Out:
# 80 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated

# %%
epochs.plot();
epochs
# Out:
# Loading data for 80 events and 141 original time points ...
# 65 bad epochs dropped
# Loading data for 15 events and 141 original time points ...
# Loading data for 15 events and 141 original time points ...
# <Epochs  |   15 events (all good), -0.2 - 0.5 sec, baseline [None, 0], ~159 kB, data not loaded,
#  'qsn end': 5
#  'qsn start': 5
#  'start count': 5>

# %%
epochs = mne.Epochs(raw, events, event_id=event_ids, preload=True)

epochs = ica.apply(epochs, exclude=ica.exclude)
# Out:
# 80 matching events found
# Applying baseline correction (mode: mean)
# Not setting metadata
# 0 projection items activated
# Loading data for 80 events and 141 original time points ...
# 65 bad epochs dropped
# Transforming to ICA space (20 components)
# Zeroing out 0 ICA components

# %%
epochs.equalize_event_counts(event_ids)
epochs
# Out:
# Dropped 0 epochs:
# <Epochs  |   15 events (all good), -0.2 - 0.5 sec, baseline [None, 0], ~1.4 MB, data loaded,
#  'qsn end': 5
#  'qsn start': 5
#  'start count': 5>

# %%
path1="/content/drive/My Drive/mukesh_sir_ml_project/"

# %%
pwd
# Out:
# '/content'

# %%
savepath=path1+"preprocessed_new"+ji+".bdf"

# %%
savepath
# Out:
# '/content/drive/My Drive/mukesh_sir_ml_project/preprocessed_new5.bdf'

# %%
epochs.save(savepath,overwrite=True)
# Out:
# Overwriting existing file.
# <ipython-input-29-c8bded4919d1>:1: RuntimeWarning: This filename (/content/drive/My Drive/mukesh_sir_ml_project/preprocessed_new5.bdf) does not conform to MNE naming conventions. All epochs files should end with -epo.fif, -epo.fif.gz, _epo.fif or _epo.fif.gz
#   epochs.save(savepath,overwrite=True)
